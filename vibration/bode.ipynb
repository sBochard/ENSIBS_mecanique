% %% [markdown]
% # Table of Contents
% * [Réponse en fréquence d'un système masse ressort](#Réponse-en-fréquence-d'un-système-masse-ressort)
% 	* &nbsp;
% 		* &nbsp;
% 			* [réponse en fréquence](#réponse-en-fréquence)

% %% [markdown]
% # Réponse en fréquence d'un système masse ressort

% %%
% chargement du package control
pkg load control
% données
m=50; % masse en kg 
k=1E6; % raideur en N/m
c=500; % amortissement en N.m/s

% %%
% construction de la fonction de trasnfert
sys=tf(1,[m c k])
% Out:
% Transfer function 'sys' from input 'u1' to output ...
%
%                1
%  y1:  --------------------
%       s^2 + 5000 s + 1e+06
%
% Continuous-time model.

% %% [markdown]
% #### réponse en fréquence

% %%
bode(sys)
